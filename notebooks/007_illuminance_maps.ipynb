# %%
from illuminance_map import maps

# %%
f = '../osm/001_iluminacion/run/000_RadianceMeasure/radiance/output/ts/Space_101/maps/Space_101_map.ill'

visualizer = maps.IlluminanceDataVisualizer(f, matrix_shape=(20, 10))
fig, ax = visualizer.visualize_udi()

# %%
visualizer.visualize_illuminance("2024-04-10 09:00:00")
