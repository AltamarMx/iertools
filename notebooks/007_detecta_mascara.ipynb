# %%
# pip install git+https://github.com/AltamarMx/iertools.git

# %%
from iertools.maps import IlluminanceDataVisualizer

# %%
f = "../OSM/Aulamilenio/000_AM_mascara/run/000_RadianceMeasure 1 1 1/radiance/output/ts/Space_101/maps/Space_101_map.ill"
am = IlluminanceDataVisualizer(f)

# %%
am.umbral_mascara=1900

# %%
am.visualize_illuminance("2024-03-10 17:00",vmax=1900,mask=True)
