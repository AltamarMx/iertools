# %%
from iertools.maps import IlluminanceDataVisualizer

# %%
f = "../OSM/Aulamilenio/000_AM_mascara/run/000_RadianceMeasure 1 1 1/radiance/output/ts/Space_101/maps/Space_101_map.ill"
am = IlluminanceDataVisualizer(f,f_mask="../masks/mascara_AulaMilenio.npy")

# %%
am.visualize_illuminance("2024-03-10 17:00",vmax=1900)

# %%
am.visualize_udi()
# Out:
# (<Figure size 1000x555.556 with 4 Axes>,
#  array([<Axes: title={'center': 'UDI < 300'}>,
#         <Axes: title={'center': '300 <= UDI <= 2000'}>,
#         <Axes: title={'center': 'UDI > 2000'}>], dtype=object))
