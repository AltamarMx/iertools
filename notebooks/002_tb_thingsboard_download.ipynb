# %%
from iertools.tb import *
import matplotlib.pyplot as plt

# %%
# pip install git+https://github.com/AltamarMx/iertools.git

# %%
fecha1 = parse("2022-04-01") 
fecha2 = fecha1 + pd.Timedelta("10D")

tmp= TB(config_file='config_gbv.ini',device_name='Termopares cafe')
sensores = ["Thermocouple_1","Thermocouple_10","Thermocouple_11",
            "Thermocouple_12","Thermocouple_2","Thermocouple_3",
            "Thermocouple_4","Thermocouple_5","Thermocouple_6",
            "Thermocouple_7","Thermocouple_8","Thermocouple_9"]
cafe = pd.concat([tmp.get_df(key=sensor,start_datetime=fecha1,end_datetime=fecha2).resample('1min').mean() for sensor in sensores],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-77bbe025901c> in <module>
#       2 fecha2 = fecha1 + pd.Timedelta("10D")
#       3
# ----> 4 tmp= TB(config_file='config_gbv.ini',device_name='Termopares cafe')
#       5 sensores = ["Thermocouple_1","Thermocouple_10","Thermocouple_11",
#       6             "Thermocouple_12","Thermocouple_2","Thermocouple_3",
#
# ~/opt/anaconda3/lib/python3.8/site-packages/iertools/tb.py in __init__(self, config_file, device_name)
#      55         headers = {'Content-Type': 'application/json', 'Accept': 'application/json'}
#      56         r = requests.post(auth_url, data=json.dumps(data), headers=headers)
# ---> 57         self.jwt_token = json.loads(r.text)['token']
#      58         timeseries = "http://{}:{}/api/plugins/telemetry/DEVICE/{}/keys/timeseries".format(self.init["host"], self.init["port"], self.init["device_id"])
#      59         headers = {"Content-Type":"application/json", "X-Authorization": "Bearer {}".format(self.jwt_token)}
#
# KeyError: 'token'

# %%
cafe.plot()
# Out:
# <AxesSubplot:xlabel='ts'>

# %%
fecha11 = parse("2022-04-07 15:30") 
fecha22 = fecha11 + pd.Timedelta("4H")


fig, ax = plt.subplots(figsize=(18,6))


ax.set_xlim(fecha11,fecha22)
for sensor in sensores:
    ax.scatter(cafe[sensor].index,cafe[sensor])
ax.set_ylim(30,38)

ax.grid()
