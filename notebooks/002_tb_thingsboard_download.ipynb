# %%
from geetools.tb import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-ca9a8ab818c1> in <module>
# ----> 1 from geetools.tb import *
#
# ModuleNotFoundError: No module named 'geetools.tb'

# %%
pip install git+https://github.com/AltamarMx/geetools
# Out:
# WARNING: Ignoring invalid distribution -hapely (/Users/gbv/opt/anaconda3/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -hapely (/Users/gbv/opt/anaconda3/lib/python3.8/site-packages)
# ...
#   Cloning https://github.com/AltamarMx/geetools to /private/var/folders/5r/jn_g7h3n0pv3v9fbjgr05h8w0000gn/T/pip-req-build-ii1k5fmn
#   Running command git clone --filter=blob:none -q https://github.com/AltamarMx/geetools /private/var/folders/5r/jn_g7h3n0pv3v9fbjgr05h8w0000gn/T/pip-req-build-ii1k5fmn
#   Resolved https://github.com/AltamarMx/geetools to commit d4071b2c76172ed4d2595a52712e07c1362f37ec
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
# ...
