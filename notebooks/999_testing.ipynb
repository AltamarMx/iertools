# %%
from iertools.maps import IlluminanceDataVisualizer

# %%
f = '../data/Space_101_map.ill'
visualizer = IlluminanceDataVisualizer(f, matrix_shape=(20, 10))

# %%
visualizer.visualize_illuminance("2024-04-10 7:00:00")
